# %%
# Import the necessary libraries
from ucimlrepo import fetch_ucirepo 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
# fetch dataset 
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697) 
  
# data (as pandas dataframes) 
X = predict_students_dropout_and_academic_success.data.features 
y = predict_students_dropout_and_academic_success.data.targets

# %%
# metadata 
#print(predict_students_dropout_and_academic_success.metadata) 
  
# variable information 
#print(predict_students_dropout_and_academic_success.variables) 

# print the first 5 rows of the dataset
# print(X.head())

# Preprocessing the data by checking for missing values
if X.isnull().sum().sum() == 0:
    print("There are no missing values in the dataset.")
else:
    print("There is a missing value in the dataset.")

# Check for duplicate rows
if X.duplicated().sum() == 0:
    print("There are no duplicate rows in the dataset.")

# Check for duplicate columns
if X.columns.duplicated().sum() == 0:
    print("There are no duplicate columns in the dataset.")

# Remove nominal features for histogram and correlation matrix
X_removed = X.drop(columns=['Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'International' ])



# Create histograms of the features


# Plot the correlation matrix
# correlation_matrix = X.corr()
# sns.heatmap(correlation_matrix, annot=True)
# Out:
# There are no missing values in the dataset.
# There are no duplicate rows in the dataset.
# There are no duplicate columns in the dataset.

# %%
X.hist(figsize=(30, 30))
plt.show()

# %%
# Plot the target variable
df = pd.DataFrame(y)
df.head()
# Plot the histogram
df['Target'].value_counts().plot(kind='bar', color=['darkblue', 'red', 'skyblue'])

# # Adding title and labels
plt.title('Comparison of Dropout, Graduate and Enrolled')
plt.xlabel('Classification')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# fetch dataset 
auto_mpg = fetch_ucirepo(id=9) 
  
# data (as pandas dataframes) 
X = auto_mpg.data.features 
y = auto_mpg.data.targets 
  
# # metadata 
# print(auto_mpg.metadata) 
  
# # variable information 
# print(auto_mpg.variables)
# Out:
#            name     role         type demographic description units  \
# 0  displacement  Feature   Continuous        None        None  None
# 1           mpg   Target   Continuous        None        None  None
# 2     cylinders  Feature      Integer        None        None  None
# 3    horsepower  Feature   Continuous        None        None  None
# 4        weight  Feature   Continuous        None        None  None
# 5  acceleration  Feature   Continuous        None        None  None
# 6    model_year  Feature      Integer        None        None  None
# 7        origin  Feature      Integer        None        None  None
# 8      car_name       ID  Categorical        None        None  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3            yes
# 4             no
# 5             no
# 6             no
# 7             no
# 8             no

# %%
X.head()
# Out:
#    displacement  cylinders  horsepower  weight  acceleration  model_year  \
# 0         307.0          8       130.0    3504          12.0          70
# 1         350.0          8       165.0    3693          11.5          70
# 2         318.0          8       150.0    3436          11.0          70
# 3         304.0          8       150.0    3433          12.0          70
# 4         302.0          8       140.0    3449          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
y.head()
# Out:
#     mpg
# 0  18.0
# 1  15.0
# 2  18.0
# 3  16.0
# 4  17.0

# %%
# Get unique values of column "cylinders"
X["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
# Validate that only column "horsepower" includes null values
X.isnull().any()
# Out:
# displacement    False
# cylinders       False
# horsepower       True
# weight          False
# acceleration    False
# model_year      False
# origin          False
# dtype: bool

# %%
# Create boolean mask for null values and filter dataset accordingly
nan_bool_mask = X.isnull().any(axis=1)

X[nan_bool_mask]
# Out:
#      displacement  cylinders  horsepower  weight  acceleration  model_year  \
# 32           98.0          4         NaN    2046          19.0          71
# 126         200.0          6         NaN    2875          17.0          74
# 330          85.0          4         NaN    1835          17.3          80
# 336         140.0          4         NaN    2905          14.3          80
# 354         100.0          4         NaN    2320          15.8          81
# 374         151.0          4         NaN    3035          20.5          82
#
#      origin
# 32        1
# 126       1
# 330       2
# 336       1
# 354       2
# 374       1

# %%
# Preprocessing the data by checking for missing values
if X.isnull().sum().sum() == 0:
    print("There are no missing values in the dataset.")
else:
    print("There is a missing value in the dataset.")

# Check for duplicate rows
if X.duplicated().sum() == 0:
    print("There are no duplicate rows in the dataset.")

# Check for duplicate columns
if X.columns.duplicated().sum() == 0:
    print("There are no duplicate columns in the dataset.")
# Out:
# There is a missing value in the dataset.
# There are no duplicate rows in the dataset.
# There are no duplicate columns in the dataset.
